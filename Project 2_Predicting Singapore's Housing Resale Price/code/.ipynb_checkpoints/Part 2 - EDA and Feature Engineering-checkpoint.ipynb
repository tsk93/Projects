# %% [markdown]
# # Part 2 - Feature Engineering & EDA

# %%
# import libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings(action='ignore', message='not allowed')
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
housing_df=pd.read_csv("../datasets/cleaned_housing_data.csv",low_memory=False)

# %%
housing_df.head()
# Out:
#        id tranc_yearmonth             town  flat_type block       street_name  \
# 0   88471         2016-05  KALLANG/WHAMPOA     4 ROOM    3B  UPP BOON KENG RD
# 1  122598         2012-07           BISHAN     5 ROOM   153      BISHAN ST 13
# 2  170897         2013-07      BUKIT BATOK  EXECUTIVE  289B    BT BATOK ST 25
# 3   86070         2012-04           BISHAN     4 ROOM   232      BISHAN ST 22
# 4  153632         2017-12           YISHUN     4 ROOM   876      YISHUN ST 81
#
#   storey_range  floor_area_sqm  flat_model  lease_commence_date  ...  vacancy  \
# 0     10 TO 12            90.0     Model A                 2006  ...       78
# 1     07 TO 09           130.0    Improved                 1987  ...       45
# 2     13 TO 15           144.0   Apartment                 1997  ...       39
# 3     01 TO 05           103.0     Model A                 1992  ...       20
# 4     01 TO 03            83.0  Simplified                 1987  ...       74
#
#    pri_sch_affiliation  pri_sch_latitude  pri_sch_longitude  \
# 0                    1          1.317659         103.882504
# 1                    1          1.349783         103.854529
# 2                    0          1.345245         103.756265
# 3                    1          1.354789         103.844934
# 4                    0          1.416280         103.838798
#
#    sec_sch_nearest_dist                             sec_sch_name  \
# 0           1138.633422                 Geylang Methodist School
# 1            447.894399  Kuo Chuan Presbyterian Secondary School
# 2            180.074558             Yusof Ishak Secondary School
# 3            389.515528                     Catholic High School
# 4            312.025435             Orchid Park Secondary School
#
#    cutoff_point sec_sch_affiliation sec_sch_latitude  sec_sch_longitude
# 0           224                   0         1.317659         103.882504
# 1           232                   0         1.350110         103.854892
# 2           188                   0         1.342334         103.760013
# 3           253                   1         1.354789         103.844934
# 4           208                   0         1.414888         103.838335
#
# [5 rows x 77 columns]

# %%
housing_df.shape
# Out:
# (56220, 77)

# %%
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56220 entries, 0 to 56219
# Data columns (total 77 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         56220 non-null  int64
#  1   tranc_yearmonth            56220 non-null  object
#  2   town                       56220 non-null  object
#  3   flat_type                  56220 non-null  object
#  4   block                      56220 non-null  object
#  5   street_name                56220 non-null  object
#  6   storey_range               56220 non-null  object
#  7   floor_area_sqm             56220 non-null  float64
#  8   flat_model                 56220 non-null  object
#  9   lease_commence_date        56220 non-null  int64
#  10  resale_price               56220 non-null  float64
#  11  tranc_year                 56220 non-null  int64
#  12  tranc_month                56220 non-null  int64
#  13  mid_storey                 56220 non-null  int64
#  14  lower                      56220 non-null  int64
#  15  upper                      56220 non-null  int64
#  16  mid                        56220 non-null  int64
#  17  full_flat_type             56220 non-null  object
#  18  address                    56220 non-null  object
#  19  floor_area_sqft            56220 non-null  float64
#  20  hdb_age                    56220 non-null  int64
#  21  max_floor_lvl              56220 non-null  int64
#  22  year_completed             56220 non-null  int64
#  23  residential                56220 non-null  object
#  24  commercial                 56220 non-null  object
#  25  market_hawker              56220 non-null  object
#  26  multistorey_carpark        56220 non-null  object
#  27  precinct_pavilion          56220 non-null  object
#  28  total_dwelling_units       56220 non-null  int64
#  29  1room_sold                 56220 non-null  int64
#  30  2room_sold                 56220 non-null  int64
#  31  3room_sold                 56220 non-null  int64
#  32  4room_sold                 56220 non-null  int64
#  33  5room_sold                 56220 non-null  int64
#  34  exec_sold                  56220 non-null  int64
#  35  multigen_sold              56220 non-null  int64
#  36  studio_apartment_sold      56220 non-null  int64
#  37  1room_rental               56220 non-null  int64
#  38  2room_rental               56220 non-null  int64
#  39  3room_rental               56220 non-null  int64
#  40  other_room_rental          56220 non-null  int64
#  41  postal                     56220 non-null  object
#  42  latitude                   56220 non-null  float64
#  43  longitude                  56220 non-null  float64
#  44  planning_area              56220 non-null  object
#  45  mall_nearest_distance      56220 non-null  float64
#  46  mall_within_500m           56220 non-null  int64
#  47  mall_within_1km            56220 non-null  int64
#  48  mall_within_2km            56220 non-null  int64
#  49  hawker_nearest_distance    56220 non-null  float64
#  50  hawker_within_500m         56220 non-null  int64
#  51  hawker_within_1km          56220 non-null  int64
#  52  hawker_within_2km          56220 non-null  int64
#  53  hawker_food_stalls         56220 non-null  int64
#  54  hawker_market_stalls       56220 non-null  int64
#  55  mrt_nearest_distance       56220 non-null  float64
#  56  mrt_name                   56220 non-null  object
#  57  bus_interchange            56220 non-null  int64
#  58  mrt_interchange            56220 non-null  int64
#  59  mrt_latitude               56220 non-null  float64
#  60  mrt_longitude              56220 non-null  float64
#  61  bus_stop_nearest_distance  56220 non-null  float64
#  62  bus_stop_name              56220 non-null  object
#  63  bus_stop_latitude          56220 non-null  float64
#  64  bus_stop_longitude         56220 non-null  float64
#  65  pri_sch_nearest_distance   56220 non-null  float64
#  66  pri_sch_name               56220 non-null  object
#  67  vacancy                    56220 non-null  int64
#  68  pri_sch_affiliation        56220 non-null  int64
#  69  pri_sch_latitude           56220 non-null  float64
#  70  pri_sch_longitude          56220 non-null  float64
#  71  sec_sch_nearest_dist       56220 non-null  float64
#  72  sec_sch_name               56220 non-null  object
#  73  cutoff_point               56220 non-null  int64
#  74  sec_sch_affiliation        56220 non-null  int64
#  75  sec_sch_latitude           56220 non-null  float64
#  76  sec_sch_longitude          56220 non-null  float64
# dtypes: float64(19), int64(38), object(20)
# memory usage: 33.0+ MB

# %%
# verify no nulls in dataset
housing_df.isnull().sum().sum()
# Out:
# 0

# %%
# convert id and postal to string datatype
housing_df['id']=housing_df['id'].map(lambda x: str(x))
housing_df['postal']=housing_df['postal'].map(lambda x: str(x))

# %%
# understanding the categorical variables in dataset and their respective unique value count
for i in list(housing_df.select_dtypes(include='object').columns):
    print (i,len(set(housing_df[i].values)))
# Out:
# id 56220
# tranc_yearmonth 110
# town 26
# flat_type 7
# block 2483
# street_name 551
# storey_range 25
# flat_model 20
# full_flat_type 42
# address 8844
# residential 1
# commercial 2
# market_hawker 2
# multistorey_carpark 2
# precinct_pavilion 2
# postal 8814
# planning_area 32
# mrt_name 94
# bus_stop_name 1645
# pri_sch_name 177
# sec_sch_name 134

# %%
# to check if median and middle storey values are different
housing_df[housing_df['mid_storey']!=housing_df['mid']].shape
# Out:
# (0, 77)

# %% [markdown]
# In the housing dataset, mid_storey and mid columns have identical values in every row. Will drop mid_storey in this dataset.

# %%
set(housing_df['residential'].values)
# Out:
# {'Y'}

# %% [markdown]
# We observe that all rows have a value of "Y" for the residential column, which suggests that every unit has residential units in the same block. This column will not be useful for analysis.

# %%
for i in ['commercial','market_hawker','multistorey_carpark','precinct_pavilion']:
    print(i,set(housing_df[i].values))
# Out:
# commercial {'Y', 'N'}
# market_hawker {'Y', 'N'}
# multistorey_carpark {'Y', 'N'}
# precinct_pavilion {'Y', 'N'}

# %% [markdown]
# As there are only 2 distinct values (Y/N) in commercial, market_hawker, multistorey_carpark and precinct_pavilion columns, we assign a value of 1 to cells containing 'Y'
# and 0 to cells containing 'N'. This helps to convert these columns into numerical data for modelling purpose. We will explore the remaining categorical variables subsequently.

# %%
# convert commercial,market_hawker,multistorey_carpark and precinct_pavilion to 1s and 0s
for i in ['commercial','market_hawker','multistorey_carpark','precinct_pavilion']:
    housing_df[i]=housing_df[i].map(lambda x: 1 if str(x).upper().strip()=='Y' else 0)

# %%
# understanding the continous variables in dataset and their respective unique value count
for i in list(housing_df.select_dtypes(exclude='object').columns):
    print (i,len(set(housing_df[i].values)))
# Out:
# floor_area_sqm 159
# lease_commence_date 54
# resale_price 2249
# tranc_year 10
# tranc_month 12
# mid_storey 22
# lower 22
# upper 23
# mid 22
# floor_area_sqft 159
# hdb_age 54
# max_floor_lvl 41
# year_completed 59
# commercial 2
# market_hawker 2
# multistorey_carpark 2
# precinct_pavilion 2
# total_dwelling_units 317
# 1room_sold 2
# 2room_sold 99
# 3room_sold 255
# 4room_sold 199
# 5room_sold 133
# exec_sold 101
# multigen_sold 5
# studio_apartment_sold 61
# 1room_rental 10
# 2room_rental 48
# 3room_rental 14
# other_room_rental 3
# latitude 8815
# longitude 8790
# mall_nearest_distance 8813
# mall_within_500m 7
# mall_within_1km 16
# mall_within_2km 42
# hawker_nearest_distance 8815
# hawker_within_500m 6
# hawker_within_1km 10
# hawker_within_2km 20
# hawker_food_stalls 52
# hawker_market_stalls 70
# mrt_nearest_distance 8815
# bus_interchange 2
# mrt_interchange 2
# mrt_latitude 94
# mrt_longitude 94
# bus_stop_nearest_distance 8814
# bus_stop_latitude 1994
# bus_stop_longitude 1990
# pri_sch_nearest_distance 8815
# vacancy 66
# pri_sch_affiliation 2
# pri_sch_latitude 177
# pri_sch_longitude 177
# sec_sch_nearest_dist 8815
# cutoff_point 54
# sec_sch_affiliation 2
# sec_sch_latitude 134
# sec_sch_longitude 134

# %%
# checking on unique values in 1room_sold and multigen_sold
for i in ['1room_sold','multigen_sold']:
    print(i,set(housing_df[i].values))
# Out:
# 1room_sold {0, 255}
# multigen_sold {0, 66, 50, 20, 22}

# %%
housing_df['1room_sold'].value_counts(ascending=False)
# Out:
# 0      56194
# 255       26
# Name: 1room_sold, dtype: int64

# %%
housing_df['multigen_sold'].value_counts(ascending=False)
# Out:
# 0     56197
# 66       10
# 22        7
# 50        3
# 20        3
# Name: multigen_sold, dtype: int64

# %%
housing_df[housing_df['1room_sold'].values==255]
# Out:
#        id tranc_yearmonth         town flat_type block         street_name  \
# 1202   13         2016-10  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES
# 2029   28         2018-08  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES
# 6257   97         2014-12  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES
# 6398   60         2012-07  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES
# 7367   31         2018-11  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES
# 8426   95         2014-12  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES
# 8937   24         2018-06  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES
# 9129   92         2014-10  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES
# 9723   41         2019-05  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES
# 10759  80         2014-01  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES
# 11535  58         2021-04  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES
# 11583  76         2013-08  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES
# 13528  93         2014-11  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES
# 14136  87         2014-07  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES
# 18682  72         2012-11  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES
# 20044  34         2019-02  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES
# 21488   6         2015-10  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES
# 29489  84         2014-06  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES
# 34299  22         2017-11  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES
# 36387  42         2019-09  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES
# 39690   3         2015-05  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES
# 40084  51         2020-11  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES
# 44126  19         2017-08  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES
# 48379  57         2021-03  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES
# 49596  75         2013-06  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES
# 50825  77         2013-09  BUKIT MERAH    1 ROOM     7  TELOK BLANGAH CRES
#
#       storey_range  floor_area_sqm flat_model  lease_commence_date  ...  \
# 1202      01 TO 03            31.0   Improved                 1975  ...
# 2029      07 TO 09            31.0   Improved                 1975  ...
# 6257      10 TO 12            31.0   Improved                 1975  ...
# 6398      01 TO 03            31.0   Improved                 1975  ...
# 7367      10 TO 12            31.0   Improved                 1975  ...
# 8426      07 TO 09            31.0   Improved                 1975  ...
# 8937      01 TO 03            31.0   Improved                 1975  ...
# 9129      04 TO 06            31.0   Improved                 1975  ...
# 9723      10 TO 12            31.0   Improved                 1975  ...
# 10759     04 TO 06            31.0   Improved                 1975  ...
# 11535     07 TO 09            31.0   Improved                 1975  ...
# 11583     07 TO 09            31.0   Improved                 1975  ...
# 13528     07 TO 09            31.0   Improved                 1975  ...
# 14136     04 TO 06            31.0   Improved                 1975  ...
# 18682     10 TO 12            31.0   Improved                 1975  ...
# 20044     10 TO 12            31.0   Improved                 1975  ...
# 21488     04 TO 06            31.0   Improved                 1975  ...
# 29489     01 TO 03            31.0   Improved                 1975  ...
# 34299     04 TO 06            31.0   Improved                 1975  ...
# 36387     04 TO 06            31.0   Improved                 1975  ...
# 39690     01 TO 03            31.0   Improved                 1975  ...
# 40084     10 TO 12            31.0   Improved                 1975  ...
# 44126     04 TO 06            31.0   Improved                 1975  ...
# 48379     01 TO 03            31.0   Improved                 1975  ...
# 49596     04 TO 06            31.0   Improved                 1975  ...
# 50825     04 TO 06            31.0   Improved                 1975  ...
#
#        vacancy  pri_sch_affiliation  pri_sch_latitude  pri_sch_longitude  \
# 1202        67                    1          1.276029         103.822344
# 2029        67                    1          1.276029         103.822344
# 6257        67                    1          1.276029         103.822344
# 6398        67                    1          1.276029         103.822344
# 7367        67                    1          1.276029         103.822344
# 8426        67                    1          1.276029         103.822344
# 8937        67                    1          1.276029         103.822344
# 9129        67                    1          1.276029         103.822344
# 9723        67                    1          1.276029         103.822344
# 10759       67                    1          1.276029         103.822344
# 11535       67                    1          1.276029         103.822344
# 11583       67                    1          1.276029         103.822344
# 13528       67                    1          1.276029         103.822344
# 14136       67                    1          1.276029         103.822344
# 18682       67                    1          1.276029         103.822344
# 20044       67                    1          1.276029         103.822344
# 21488       67                    1          1.276029         103.822344
# 29489       67                    1          1.276029         103.822344
# 34299       67                    1          1.276029         103.822344
# 36387       67                    1          1.276029         103.822344
# 39690       67                    1          1.276029         103.822344
# 40084       67                    1          1.276029         103.822344
# 44126       67                    1          1.276029         103.822344
# 48379       67                    1          1.276029         103.822344
# 49596       67                    1          1.276029         103.822344
# 50825       67                    1          1.276029         103.822344
#
#        sec_sch_nearest_dist                  sec_sch_name  cutoff_point  \
# 1202             418.947636  CHIJ Saint Theresa's Convent           235
# 2029             418.947636  CHIJ Saint Theresa's Convent           235
# 6257             418.947636  CHIJ Saint Theresa's Convent           235
# 6398             418.947636  CHIJ Saint Theresa's Convent           235
# 7367             418.947636  CHIJ Saint Theresa's Convent           235
# 8426             418.947636  CHIJ Saint Theresa's Convent           235
# 8937             418.947636  CHIJ Saint Theresa's Convent           235
# 9129             418.947636  CHIJ Saint Theresa's Convent           235
# 9723             418.947636  CHIJ Saint Theresa's Convent           235
# 10759            418.947636  CHIJ Saint Theresa's Convent           235
# 11535            418.947636  CHIJ Saint Theresa's Convent           235
# 11583            418.947636  CHIJ Saint Theresa's Convent           235
# 13528            418.947636  CHIJ Saint Theresa's Convent           235
# 14136            418.947636  CHIJ Saint Theresa's Convent           235
# 18682            418.947636  CHIJ Saint Theresa's Convent           235
# 20044            418.947636  CHIJ Saint Theresa's Convent           235
# 21488            418.947636  CHIJ Saint Theresa's Convent           235
# 29489            418.947636  CHIJ Saint Theresa's Convent           235
# 34299            418.947636  CHIJ Saint Theresa's Convent           235
# 36387            418.947636  CHIJ Saint Theresa's Convent           235
# 39690            418.947636  CHIJ Saint Theresa's Convent           235
# 40084            418.947636  CHIJ Saint Theresa's Convent           235
# 44126            418.947636  CHIJ Saint Theresa's Convent           235
# 48379            418.947636  CHIJ Saint Theresa's Convent           235
# 49596            418.947636  CHIJ Saint Theresa's Convent           235
# 50825            418.947636  CHIJ Saint Theresa's Convent           235
#
#       sec_sch_affiliation sec_sch_latitude  sec_sch_longitude
# 1202                    0         1.276029         103.822344
# 2029                    0         1.276029         103.822344
# 6257                    0         1.276029         103.822344
# 6398                    0         1.276029         103.822344
# 7367                    0         1.276029         103.822344
# 8426                    0         1.276029         103.822344
# 8937                    0         1.276029         103.822344
# 9129                    0         1.276029         103.822344
# 9723                    0         1.276029         103.822344
# 10759                   0         1.276029         103.822344
# 11535                   0         1.276029         103.822344
# 11583                   0         1.276029         103.822344
# 13528                   0         1.276029         103.822344
# 14136                   0         1.276029         103.822344
# 18682                   0         1.276029         103.822344
# 20044                   0         1.276029         103.822344
# 21488                   0         1.276029         103.822344
# 29489                   0         1.276029         103.822344
# 34299                   0         1.276029         103.822344
# 36387                   0         1.276029         103.822344
# 39690                   0         1.276029         103.822344
# 40084                   0         1.276029         103.822344
# 44126                   0         1.276029         103.822344
# 48379                   0         1.276029         103.822344
# 49596                   0         1.276029         103.822344
# 50825                   0         1.276029         103.822344
#
# [26 rows x 77 columns]

# %%
for i in ['block','street_name','flat_type','flat_model']:
    print(i,set(housing_df[housing_df['1room_sold'].values==255][i].values))
# Out:
# block {'7'}
# street_name {'TELOK BLANGAH CRES'}
# flat_type {'1 ROOM'}
# flat_model {'Improved'}

# %% [markdown]
# We observe all the 1 room flats sold are only coming from Blk 7, Telok Blangah Crescent, to also note that data is limited.

# %%
housing_df[housing_df['multigen_sold'].values>0]
# Out:
#            id tranc_yearmonth      town         flat_type block  \
# 2023   185955         2019-08    YISHUN  MULTI-GENERATION   666
# 2927    35603         2012-05    YISHUN  MULTI-GENERATION   605
# 3194    35597         2017-05    YISHUN            4 ROOM   605
# 5592   185951         2018-10    YISHUN  MULTI-GENERATION   666
# 9849   185923         2019-06  TAMPINES  MULTI-GENERATION   460
# 15015  185949         2018-09    YISHUN  MULTI-GENERATION   666
# 18775  185950         2018-09    YISHUN  MULTI-GENERATION   666
# 18987   56600         2016-03    YISHUN            3 ROOM   632
# 21749  185931         2018-08    YISHUN  MULTI-GENERATION   633
# 26522   35593         2012-03    YISHUN            3 ROOM   605
# 28157   35602         2019-05    YISHUN  MULTI-GENERATION   605
# 33436  185946         2018-04    YISHUN  MULTI-GENERATION   666
# 35428   35599         2013-05    YISHUN            4 ROOM   605
# 38542  185952         2018-11    YISHUN  MULTI-GENERATION   666
# 39886   35601         2018-10    YISHUN  MULTI-GENERATION   605
# 42207   35604         2013-08    YISHUN  MULTI-GENERATION   605
# 42833  185915         2016-05  TAMPINES  MULTI-GENERATION   460
# 47801  185945         2017-11    YISHUN  MULTI-GENERATION   666
# 47971  185924         2020-09  TAMPINES  MULTI-GENERATION   460
# 49846   56601         2016-08    YISHUN            3 ROOM   632
# 52691  185932         2019-04    YISHUN  MULTI-GENERATION   633
# 54116   56602         2017-12    YISHUN            3 ROOM   632
# 54334  185954         2019-07    YISHUN  MULTI-GENERATION   666
#
#           street_name storey_range  floor_area_sqm        flat_model  \
# 2023     YISHUN AVE 4     04 TO 06           179.0  Multi Generation
# 2927     YISHUN ST 61     06 TO 10           163.0  Multi Generation
# 3194     YISHUN ST 61     10 TO 12            91.0        Simplified
# 5592     YISHUN AVE 4     07 TO 09           179.0  Multi Generation
# 9849   TAMPINES ST 42     07 TO 09           166.0  Multi Generation
# 15015    YISHUN AVE 4     04 TO 06           179.0  Multi Generation
# 18775    YISHUN AVE 4     10 TO 12           179.0  Multi Generation
# 18987    YISHUN ST 61     07 TO 09            64.0        Simplified
# 21749    YISHUN ST 61     07 TO 09           171.0  Multi Generation
# 26522    YISHUN ST 61     11 TO 15            64.0        Simplified
# 28157    YISHUN ST 61     07 TO 09           159.0  Multi Generation
# 33436    YISHUN AVE 4     07 TO 09           164.0  Multi Generation
# 35428    YISHUN ST 61     04 TO 06            91.0        Simplified
# 38542    YISHUN AVE 4     04 TO 06           164.0  Multi Generation
# 39886    YISHUN ST 61     01 TO 03           163.0  Multi Generation
# 42207    YISHUN ST 61     10 TO 12           147.0  Multi Generation
# 42833  TAMPINES ST 42     07 TO 09           166.0  Multi Generation
# 47801    YISHUN AVE 4     01 TO 03           179.0  Multi Generation
# 47971  TAMPINES ST 42     07 TO 09           132.0  Multi Generation
# 49846    YISHUN ST 61     01 TO 03            64.0        Simplified
# 52691    YISHUN ST 61     07 TO 09           164.0  Multi Generation
# 54116    YISHUN ST 61     10 TO 12            64.0        Simplified
# 54334    YISHUN AVE 4     10 TO 12           164.0  Multi Generation
#
#        lease_commence_date  ...  vacancy  pri_sch_affiliation  \
# 2023                  1987  ...       53                    0
# 2927                  1988  ...       53                    0
# 3194                  1988  ...       53                    0
# 5592                  1987  ...       53                    0
# 9849                  1987  ...       38                    0
# 15015                 1987  ...       53                    0
# 18775                 1987  ...       53                    0
# 18987                 1987  ...       74                    0
# 21749                 1987  ...       74                    0
# 26522                 1988  ...       53                    0
# 28157                 1988  ...       53                    0
# 33436                 1987  ...       53                    0
# 35428                 1988  ...       53                    0
# 38542                 1987  ...       53                    0
# 39886                 1988  ...       53                    0
# 42207                 1988  ...       53                    0
# 42833                 1987  ...       38                    0
# 47801                 1987  ...       53                    0
# 47971                 1987  ...       38                    0
# 49846                 1987  ...       74                    0
# 52691                 1987  ...       74                    0
# 54116                 1987  ...       74                    0
# 54334                 1987  ...       53                    0
#
#        pri_sch_latitude  pri_sch_longitude  sec_sch_nearest_dist  \
# 2023           1.421304         103.840793            552.426214
# 2927           1.421304         103.840793            649.758838
# 3194           1.421304         103.840793            649.758838
# 5592           1.421304         103.840793            552.426214
# 9849           1.357349         103.948872            283.425250
# 15015          1.421304         103.840793            552.426214
# 18775          1.421304         103.840793            552.426214
# 18987          1.416280         103.838798            419.925886
# 21749          1.416280         103.838798            451.382126
# 26522          1.421304         103.840793            649.758838
# 28157          1.421304         103.840793            649.758838
# 33436          1.421304         103.840793            552.426214
# 35428          1.421304         103.840793            649.758838
# 38542          1.421304         103.840793            552.426214
# 39886          1.421304         103.840793            649.758838
# 42207          1.421304         103.840793            649.758838
# 42833          1.357349         103.948872            283.425250
# 47801          1.421304         103.840793            552.426214
# 47971          1.357349         103.948872            283.425250
# 49846          1.416280         103.838798            419.925886
# 52691          1.416280         103.838798            451.382126
# 54116          1.416280         103.838798            419.925886
# 54334          1.421304         103.840793            552.426214
#
#                        sec_sch_name  cutoff_point sec_sch_affiliation  \
# 2023   Orchid Park Secondary School           208                   0
# 2927    Naval Base Secondary School           195                   0
# 3194    Naval Base Secondary School           195                   0
# 5592   Orchid Park Secondary School           208                   0
# 9849        Dunman Secondary School           229                   0
# 15015  Orchid Park Secondary School           208                   0
# 18775  Orchid Park Secondary School           208                   0
# 18987  Orchid Park Secondary School           208                   0
# 21749  Orchid Park Secondary School           208                   0
# 26522   Naval Base Secondary School           195                   0
# 28157   Naval Base Secondary School           195                   0
# 33436  Orchid Park Secondary School           208                   0
# 35428   Naval Base Secondary School           195                   0
# 38542  Orchid Park Secondary School           208                   0
# 39886   Naval Base Secondary School           195                   0
# 42207   Naval Base Secondary School           195                   0
# 42833       Dunman Secondary School           229                   0
# 47801  Orchid Park Secondary School           208                   0
# 47971       Dunman Secondary School           229                   0
# 49846  Orchid Park Secondary School           208                   0
# 52691  Orchid Park Secondary School           208                   0
# 54116  Orchid Park Secondary School           208                   0
# 54334  Orchid Park Secondary School           208                   0
#
#       sec_sch_latitude  sec_sch_longitude
# 2023          1.414888         103.838335
# 2927          1.419245         103.831044
# 3194          1.419245         103.831044
# 5592          1.414888         103.838335
# 9849          1.360548         103.956207
# 15015         1.414888         103.838335
# 18775         1.414888         103.838335
# 18987         1.414888         103.838335
# 21749         1.414888         103.838335
# 26522         1.419245         103.831044
# 28157         1.419245         103.831044
# 33436         1.414888         103.838335
# 35428         1.419245         103.831044
# 38542         1.414888         103.838335
# 39886         1.419245         103.831044
# 42207         1.419245         103.831044
# 42833         1.360548         103.956207
# 47801         1.414888         103.838335
# 47971         1.360548         103.956207
# 49846         1.414888         103.838335
# 52691         1.414888         103.838335
# 54116         1.414888         103.838335
# 54334         1.414888         103.838335
#
# [23 rows x 77 columns]

# %%
for i in ['block','street_name','flat_type','flat_model','town','planning_area']:
    print(i,set(housing_df[housing_df['multigen_sold'].values>0][i].values))
# Out:
# block {'632', '605', '666', '460', '633'}
# street_name {'YISHUN ST 61', 'TAMPINES ST 42', 'YISHUN AVE 4'}
# flat_type {'3 ROOM', '4 ROOM', 'MULTI-GENERATION'}
# flat_model {'Simplified', 'Multi Generation'}
# town {'YISHUN', 'TAMPINES'}
# planning_area {'Tampines', 'Yishun'}

# %% [markdown]
# Some of the rows consist 3 and 4 room flats, this only tells us that certain blocks have a mixture of 3 room/4 room/multi-generation flats. We refine the search criteria by looking at the rows with Multi Generation flat model.

# %%
housing_df[(housing_df['multigen_sold'].values>0) & (housing_df['flat_model']=='Multi Generation')]
# Out:
#            id tranc_yearmonth      town         flat_type block  \
# 2023   185955         2019-08    YISHUN  MULTI-GENERATION   666
# 2927    35603         2012-05    YISHUN  MULTI-GENERATION   605
# 5592   185951         2018-10    YISHUN  MULTI-GENERATION   666
# 9849   185923         2019-06  TAMPINES  MULTI-GENERATION   460
# 15015  185949         2018-09    YISHUN  MULTI-GENERATION   666
# 18775  185950         2018-09    YISHUN  MULTI-GENERATION   666
# 21749  185931         2018-08    YISHUN  MULTI-GENERATION   633
# 28157   35602         2019-05    YISHUN  MULTI-GENERATION   605
# 33436  185946         2018-04    YISHUN  MULTI-GENERATION   666
# 38542  185952         2018-11    YISHUN  MULTI-GENERATION   666
# 39886   35601         2018-10    YISHUN  MULTI-GENERATION   605
# 42207   35604         2013-08    YISHUN  MULTI-GENERATION   605
# 42833  185915         2016-05  TAMPINES  MULTI-GENERATION   460
# 47801  185945         2017-11    YISHUN  MULTI-GENERATION   666
# 47971  185924         2020-09  TAMPINES  MULTI-GENERATION   460
# 52691  185932         2019-04    YISHUN  MULTI-GENERATION   633
# 54334  185954         2019-07    YISHUN  MULTI-GENERATION   666
#
#           street_name storey_range  floor_area_sqm        flat_model  \
# 2023     YISHUN AVE 4     04 TO 06           179.0  Multi Generation
# 2927     YISHUN ST 61     06 TO 10           163.0  Multi Generation
# 5592     YISHUN AVE 4     07 TO 09           179.0  Multi Generation
# 9849   TAMPINES ST 42     07 TO 09           166.0  Multi Generation
# 15015    YISHUN AVE 4     04 TO 06           179.0  Multi Generation
# 18775    YISHUN AVE 4     10 TO 12           179.0  Multi Generation
# 21749    YISHUN ST 61     07 TO 09           171.0  Multi Generation
# 28157    YISHUN ST 61     07 TO 09           159.0  Multi Generation
# 33436    YISHUN AVE 4     07 TO 09           164.0  Multi Generation
# 38542    YISHUN AVE 4     04 TO 06           164.0  Multi Generation
# 39886    YISHUN ST 61     01 TO 03           163.0  Multi Generation
# 42207    YISHUN ST 61     10 TO 12           147.0  Multi Generation
# 42833  TAMPINES ST 42     07 TO 09           166.0  Multi Generation
# 47801    YISHUN AVE 4     01 TO 03           179.0  Multi Generation
# 47971  TAMPINES ST 42     07 TO 09           132.0  Multi Generation
# 52691    YISHUN ST 61     07 TO 09           164.0  Multi Generation
# 54334    YISHUN AVE 4     10 TO 12           164.0  Multi Generation
#
#        lease_commence_date  ...  vacancy  pri_sch_affiliation  \
# 2023                  1987  ...       53                    0
# 2927                  1988  ...       53                    0
# 5592                  1987  ...       53                    0
# 9849                  1987  ...       38                    0
# 15015                 1987  ...       53                    0
# 18775                 1987  ...       53                    0
# 21749                 1987  ...       74                    0
# 28157                 1988  ...       53                    0
# 33436                 1987  ...       53                    0
# 38542                 1987  ...       53                    0
# 39886                 1988  ...       53                    0
# 42207                 1988  ...       53                    0
# 42833                 1987  ...       38                    0
# 47801                 1987  ...       53                    0
# 47971                 1987  ...       38                    0
# 52691                 1987  ...       74                    0
# 54334                 1987  ...       53                    0
#
#        pri_sch_latitude  pri_sch_longitude  sec_sch_nearest_dist  \
# 2023           1.421304         103.840793            552.426214
# 2927           1.421304         103.840793            649.758838
# 5592           1.421304         103.840793            552.426214
# 9849           1.357349         103.948872            283.425250
# 15015          1.421304         103.840793            552.426214
# 18775          1.421304         103.840793            552.426214
# 21749          1.416280         103.838798            451.382126
# 28157          1.421304         103.840793            649.758838
# 33436          1.421304         103.840793            552.426214
# 38542          1.421304         103.840793            552.426214
# 39886          1.421304         103.840793            649.758838
# 42207          1.421304         103.840793            649.758838
# 42833          1.357349         103.948872            283.425250
# 47801          1.421304         103.840793            552.426214
# 47971          1.357349         103.948872            283.425250
# 52691          1.416280         103.838798            451.382126
# 54334          1.421304         103.840793            552.426214
#
#                        sec_sch_name  cutoff_point sec_sch_affiliation  \
# 2023   Orchid Park Secondary School           208                   0
# 2927    Naval Base Secondary School           195                   0
# 5592   Orchid Park Secondary School           208                   0
# 9849        Dunman Secondary School           229                   0
# 15015  Orchid Park Secondary School           208                   0
# 18775  Orchid Park Secondary School           208                   0
# 21749  Orchid Park Secondary School           208                   0
# 28157   Naval Base Secondary School           195                   0
# 33436  Orchid Park Secondary School           208                   0
# 38542  Orchid Park Secondary School           208                   0
# 39886   Naval Base Secondary School           195                   0
# 42207   Naval Base Secondary School           195                   0
# 42833       Dunman Secondary School           229                   0
# 47801  Orchid Park Secondary School           208                   0
# 47971       Dunman Secondary School           229                   0
# 52691  Orchid Park Secondary School           208                   0
# 54334  Orchid Park Secondary School           208                   0
#
#       sec_sch_latitude  sec_sch_longitude
# 2023          1.414888         103.838335
# 2927          1.419245         103.831044
# 5592          1.414888         103.838335
# 9849          1.360548         103.956207
# 15015         1.414888         103.838335
# 18775         1.414888         103.838335
# 21749         1.414888         103.838335
# 28157         1.419245         103.831044
# 33436         1.414888         103.838335
# 38542         1.414888         103.838335
# 39886         1.419245         103.831044
# 42207         1.419245         103.831044
# 42833         1.360548         103.956207
# 47801         1.414888         103.838335
# 47971         1.360548         103.956207
# 52691         1.414888         103.838335
# 54334         1.414888         103.838335
#
# [17 rows x 77 columns]

# %%
for i in ['block','street_name','flat_type','flat_model','town','planning_area']:
    print(i,set(housing_df[housing_df['multigen_sold'].values>0][i].values))
# Out:
# block {'632', '605', '666', '460', '633'}
# street_name {'YISHUN ST 61', 'TAMPINES ST 42', 'YISHUN AVE 4'}
# flat_type {'3 ROOM', '4 ROOM', 'MULTI-GENERATION'}
# flat_model {'Simplified', 'Multi Generation'}
# town {'YISHUN', 'TAMPINES'}
# planning_area {'Tampines', 'Yishun'}

# %% [markdown]
# We get the same results as above, to also note that data is limited and multi-generation flats only come from Bishan, Tampines and Yishun (town/planning area).

# %% [markdown]
# ### Resale price study on categorical features

# %% [markdown]
# This section studies some categorical features in the dataset to understand if they have a role in determining resale price.

# %% [markdown]
# #### 1. Flat Type

# %%
# median price sort by flat type, descending order
housing_df.groupby('flat_type')['resale_price'].median().sort_values(ascending=False)
# Out:
# flat_type
# MULTI-GENERATION    753888.0
# EXECUTIVE           615000.0
# 5 ROOM              500000.0
# 4 ROOM              421000.0
# 3 ROOM              315000.0
# 2 ROOM              245000.0
# 1 ROOM              207500.0
# Name: resale_price, dtype: float64

# %%
#boxplot of resale price by flat type, ordering done from highest to lowest median resale price
fig,axes=plt.subplots(figsize=(15,8))
sns.boxplot(y='resale_price', x='flat_type', data=housing_df,
            order=housing_df.groupby('flat_type')['resale_price'].median()
            .sort_values(ascending=False).index).set_title("Resale Price by Flat Type",fontsize=16)
plt.xlabel(xlabel='Flat Type', fontsize=12)
plt.ylabel(ylabel='Resale Price',fontsize=12)
plt.show()

# %% [markdown]
# From above boxplot, we observe that flat type has a significant influence on resale price.

# %% [markdown]
# #### 2. Flat Model

# %%
# median price sort by flat model, descending order
housing_df.groupby('flat_model')['resale_price'].median().sort_values(ascending=False)
# Out:
# flat_model
# Type S2                   1000000.0
# Type S1                    900000.0
# Premium Apartment Loft     874000.0
# Terrace                    831500.0
# Multi Generation           753888.0
# DBSS                       745000.0
# Premium Maisonette         742500.0
# Model A-Maisonette         700000.0
# Adjoined flat              689444.0
# Improved-Maisonette        660000.0
# Maisonette                 650000.0
# Apartment                  600000.0
# Premium Apartment          470000.0
# Improved                   453000.0
# Model A                    415000.0
# Model A2                   365000.0
# Simplified                 350000.0
# New Generation             340000.0
# Standard                   322000.0
# 2-room                     251000.0
# Name: resale_price, dtype: float64

# %%
#boxplot of resale price by flat model, ordering done from highest to lowest median resale price
fig,axes=plt.subplots(figsize=(16,9))
sns.boxplot(x='resale_price', y='flat_model', data=housing_df,
            order=housing_df.groupby('flat_model')['resale_price'].median()
            .sort_values(ascending=False).index).set_title("Resale Price by Flat Model",fontsize=16)
plt.ylabel(ylabel='Flat Model', fontsize=12)
plt.xlabel(xlabel='Resale Price',fontsize=12)
plt.show()

# %% [markdown]
# From above boxplot, we observe that flat model has a significant influence on resale price.

# %% [markdown]
# #### 3. Planning Area

# %%
# median price sort by planning area, descending order
housing_df.groupby('planning_area')['resale_price'].median().sort_values(ascending=False)
# Out:
# planning_area
# Tanglin                    855000.0
# Outram                     820000.0
# Bukit Timah                695000.0
# Downtown Core              637500.0
# Bishan                     600000.0
# Bukit Merah                570000.0
# Queenstown                 530888.0
# Pasir Ris                  482500.0
# Marine Parade              475000.0
# Kallang                    468000.0
# Serangoon                  465400.0
# Punggol                    460000.0
# Tampines                   460000.0
# Sengkang                   450000.0
# Rochor                     445000.0
# Western Water Catchment    433500.0
# Bukit Panjang              428000.0
# Hougang                    420000.0
# Jurong West                413000.0
# Sembawang                  406000.0
# Clementi                   405000.0
# Choa Chu Kang              405000.0
# Jurong East                405000.0
# Toa Payoh                  400000.0
# Woodlands                  390000.0
# Bedok                      380000.0
# Geylang                    375000.0
# Bukit Batok                372000.0
# Ang Mo Kio                 368000.0
# Novena                     360000.0
# Yishun                     358000.0
# Changi                     297500.0
# Name: resale_price, dtype: float64

# %%
#boxplot of resale price by planning area, ordering done from highest to lowest median resale price
fig,axes=plt.subplots(figsize=(16,9))
sns.boxplot(x='resale_price', y='planning_area', data=housing_df, order=housing_df.groupby('planning_area')['resale_price'].median()
            .sort_values(ascending=False).index, palette="colorblind").set_title("Resale Price by Planning Area",fontsize=16)
plt.ylabel(ylabel='Planning Area', fontsize=12)
plt.xlabel(xlabel='Resale Price',fontsize=12)
plt.show()

# %% [markdown]
# From above boxplot, we observe that different government planning areas for housing in Singapore command different resale prices.

# %% [markdown]
# #### 4. Town

# %%
# median price sort by town, descending order
housing_df.groupby('town')['resale_price'].median().sort_values(ascending=False)
# Out:
# town
# BUKIT TIMAH        703000.0
# BISHAN             600000.0
# BUKIT MERAH        570000.0
# QUEENSTOWN         535000.0
# CENTRAL AREA       506000.0
# PASIR RIS          480000.0
# MARINE PARADE      475888.0
# SERANGOON          465000.0
# TAMPINES           460000.0
# PUNGGOL            460000.0
# SENGKANG           450000.0
# KALLANG/WHAMPOA    441000.0
# BUKIT PANJANG      428000.0
# HOUGANG            420000.0
# JURONG WEST        413000.0
# SEMBAWANG          406000.0
# JURONG EAST        405000.0
# CLEMENTI           405000.0
# CHOA CHU KANG      405000.0
# TOA PAYOH          400000.0
# WOODLANDS          390000.0
# BEDOK              380000.0
# GEYLANG            375000.0
# BUKIT BATOK        375000.0
# ANG MO KIO         368000.0
# YISHUN             358000.0
# Name: resale_price, dtype: float64

# %%
#boxplot of resale price by flat model, ordering done from highest to lowest median resale price
fig,axes=plt.subplots(figsize=(16,9))
sns.boxplot(x='resale_price', y='town', data=housing_df, order=housing_df.groupby('town')['resale_price'].median()
            .sort_values(ascending=False).index, palette="colorblind").set_title("Resale Price by Town",fontsize=16)
plt.ylabel(ylabel='Town', fontsize=12)
plt.xlabel(xlabel='Resale Price',fontsize=12)
plt.show()

# %% [markdown]
# From above boxplot, we observe that different HDB township where flat is located in Singapore command different resale prices.

# %% [markdown]
# #### 5. Other neighbourhood facilities

# %%
#to check resale price response against other numeric variables (those that consist of 1s and 0s, 1=Yes and 0=No)

var=['bus_interchange','mrt_interchange','pri_sch_affiliation','sec_sch_affiliation','market_hawker',
     'precinct_pavilion','multistorey_carpark','commercial']
i=0
fig,axes=plt.subplots(2,4,figsize=(30,15))
for k in range(len(var)):
    sns.boxplot(y='resale_price',x=var[k],data=housing_df,ax=axes[i//4,i%4])
    axes[i//4,i%4].set_ylabel(ylabel='Resale Price', fontsize=14)
    axes[i//4,i%4].set_xticklabels(['No','Yes'],fontsize=14)
    axes[i//4,i%4].set_xlabel(xlabel=var[k].replace('_',' '),fontsize=14)
    i+=1
fig.suptitle('Resale price boxplot comparison across other amenities',fontsize=20)       
plt.show()

# %% [markdown]
# We aim to check if these neighbourhood facilities are significant in determining resale price regardless of flat type/model. From above boxplots, we do not observe any significant change in resale price in the presence/absence of these features.

# %% [markdown]
# ### Removing Multicollinearity

# %% [markdown]
# A crucial factor in linear regression modelling is to analyse the relationship between each independent variable and the dependent variable. The interpretation of a regression coefficient is that it represents the mean change in the dependent variable for each 1 unit change in an independent variable, assuming all other independent variables are held constant.
#
# Multicollinearity occurs when several independent variables in a model are correlated. Two variables are considered to be perfectly collinear if their correlation coefficient is +/- 1. When independent variables are correlated, it indicates that changes in one variable are associated with shifts in other variables. The stronger the correlation, the more difficult it is to change one variable without changing another. It becomes difficult for the model to estimate the relationship between each independent variable and the dependent variable on a 1 to 1 basis, hence lowering the accuracy of the estimated coefficients and therefore resulting in less reliable statistical inferences.

# %%
# to check for multicollinearity among independent variables

fig, ax = plt.subplots(figsize=(10,8)) 
mc=housing_df[['lower','upper','mid','floor_area_sqft','floor_area_sqm','hdb_age','year_completed','max_floor_lvl',
               'lease_commence_date','mall_nearest_distance','mall_within_500m', 'mall_within_1km', 'mall_within_2km',
               'hawker_nearest_distance', 'hawker_within_500m', 'hawker_within_1km','hawker_within_2km']]
mask=np.triu(np.ones_like(mc.corr()))
sns.heatmap(mc.corr(),mask=mask,
            annot=True, linewidths=0.5, square=True,
            center=0, fmt='0.2f')
plt.title('Housing data correlation heatmap on selected features')
plt.show()

# %% [markdown]
# From above heatmap, we observe several correlations between independent variables.
#
# 1. Correlation between hdb_age, lease_commence_date and year_completed:
#     <br>
#     HDB age is the difference between current year and lease commencement year, and the year completed can be expressed as a linear function of the lease commencement year, therefore high correlation is expected.<br><br>
# 2. Correlation between upper, mid and lower:
#    <br>
#    Mid is the average of upper and lower values, high correlation is expected.<br><br>
# 3. Correlation between floor_area_sqft and floor_area_sqm:
#    <br>
#    Area unit conversion between variables, high correlation is expected.

# %% [markdown]
# In the context of our model, we will be using hdb_age, mid and floor_area_sqft only to avoid multicollinearity. HDB age is easier to interpret as it reflects the "age" or remaining lease of a housing unit, as compared to year_completed or lease_commence_date. Square feet is a common metric used to represent the area of a housing unit.

# %% [markdown]
# ### Resale price correlation study with housing features

# %%
# corr between resale price and hdb age
ax=sns.lmplot(x='hdb_age',y='resale_price',
              scatter_kws={'s':0.5},line_kws={'color':'red'},data=housing_df,height=6,aspect=1.2)
ax.set(xlabel='HDB Age', ylabel='Resale Price')
plt.title('Correlation between resale price and HDB age',fontsize=10)
plt.show()

# %% [markdown]
# We observe resale price decreases with HDB age, this makes sense as older units tend to be less appealing, especially to the younger buyers that are not able to utilise their full CPF or due to a building's deteriorating exterior condition that puts buyers off.

# %%
# corr between resale price and floor area
ax=sns.lmplot(x='floor_area_sqft',y='resale_price',
           scatter_kws={'s':0.5},line_kws={'color': 'black'},data=housing_df,height=6, aspect=1.2)
ax.set(xlabel='Floor Area', ylabel='Resale Price')
plt.title('Correlation between resale price and floor area (sqft)',fontsize=10)
plt.show()

# %% [markdown]
# We observe resale price increases with floor area, this makes sense as land is scarce in Singapore and people would have to pay more to get a larger home.

# %%
# corr between resale price and middle of storey range
ax=sns.lmplot(x='mid',y='resale_price',
           scatter_kws={'s':0.5},line_kws={'color': 'black'},data=housing_df,height=6, aspect=1.2)
ax.set(xlabel='Middle of storey range', ylabel='Resale Price')
plt.title('Correlation between resale price and middle of storey range',fontsize=10)
plt.show()

# %% [markdown]
# We observe resale price increases with storey range, this makes sense as units located on the higher floors are preferred. At the lower levels, it might be noiser or dirtier as the units are generally closer to the rubbish chutes. The quality of air might be another factor at play here as well.

# %%
# corr between resale price and max floor level
ax=sns.lmplot(x='max_floor_lvl',y='resale_price',
           scatter_kws={'s':0.5},line_kws={'color': 'black'},data=housing_df,height=6, aspect=1.2)
ax.set(xlabel='Max Floor Level', ylabel='Resale Price')
plt.title('Correlation between resale price and max floor level',fontsize=10)
plt.show()

# %% [markdown]
# Same observation as middle storey range, generally resale price increases. The higher the maximum floor level, the more appealing to buyers as it appears that they would have more privacy since there's a higher chance of avoiding the lower levels.

# %%
# corr between resale price and mrt nearest distance
ax=sns.lmplot(x='mrt_nearest_distance',y='resale_price',
           scatter_kws={'s':0.5},line_kws={'color': 'black'},data=housing_df,height=6,aspect=1.2)
ax.set(xlabel='Nearest distance from MRT', ylabel='Resale Price')
plt.title('Correlation between resale price and nearest distance from MRT',fontsize=10)
plt.show()

# %% [markdown]
# Resale price decreases as the distance from housing unit to MRT increases. This is probably due to the fact that the value of a unit increases as it is nearer to various amenities/facilities.

# %%
# corr between resale price and hawker nearest distance
ax=sns.lmplot(x='hawker_nearest_distance',y='resale_price',
           scatter_kws={'s':0.5},line_kws={'color': 'black'},data=housing_df,height=6,aspect=1.2)
ax.set(xlabel='Nearest distance from hawker', ylabel='Resale Price')
plt.title('Correlation between resale price and nearest distance from hawker',fontsize=10)
plt.show()

# %% [markdown]
# Resale price decreases as the distance from housing unit to hawker centres increases. However the decrease is not very significant, this might suggest that it is not a huge concern as people have different food preferences or they can get food from other places (eg. fast food chains/markets/provision shops that are nearby)

# %%
# corr between resale price and mall nearest distance
ax=sns.lmplot(x='mall_nearest_distance',y='resale_price',
           scatter_kws={'s':0.5},line_kws={'color': 'black'},data=housing_df,height=6,aspect=1.2)
ax.set(xlabel='Nearest distance from mall', ylabel='Resale Price')
plt.title('Correlation between resale price and nearest distance from mall',fontsize=10)
plt.show()

# %% [markdown]
# Resale price decreases as the distance from housing unit to malls increases. This is probably due to the fact that the value of a unit increases as it is nearer to various amenities/facilities.

# %%
# corr between resale price and pri sch nearest distance
ax=sns.lmplot(x='pri_sch_nearest_distance',y='resale_price',
           scatter_kws={'s':0.5},line_kws={'color': 'black'},data=housing_df,height=6,aspect=1.2)
ax.set(xlabel='Nearest distance from primary school', ylabel='Resale Price')
plt.title('Correlation between resale price and primary school nearest distance',fontsize=10)
plt.show()

# %% [markdown]
# Resale price decreases as the distance from housing unit to primary schools increases. However the decrease is not very significant, this might suggest that it is not a huge concern as parents are able to send their children to school or there might be bus services provided by the school itself. Hence distance does not seem to be a major concern here.

# %%
# corr between resale price and sec sch nearest distance
ax=sns.lmplot(x='sec_sch_nearest_dist',y='resale_price',
           scatter_kws={'s':0.5},line_kws={'color': 'black'},data=housing_df,height=6,aspect=1.2)
ax.set(xlabel='Nearest distance from secondary school', ylabel='Resale Price')
plt.title('Correlation between resale price and secondary school nearest distance',fontsize=10)
plt.show()

# %% [markdown]
# Resale price increases as the distance from housing unit to secondary schools increases. This does not seem to be intuitive, nevertheless we will include this observation into our modelling and verify the coefficients later.

# %%
# save and export data for modelling after dropping columns
housing_df.to_csv("../datasets/modelling_housing_data.csv",index=False)
